# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene":{"$eq":20}}
results = establishments.find(query)

# Use count_documents to display the number of documents in the result
print(f"No of documents in the result is: {establishments.count_documents(query)}")
# Display the first document in the results using pprint
print("Result of the first document:")
pprint(results[0], sort_dicts=False)
# Out:
# No of documents in the result is: 41
# Result of the first document:
# {'_id': ObjectId('6532a0e27cf1a2608b4da18a'),
#  'FHRSID': 110681,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '4029',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'PostCode': 'BN21 1BU',
#  'Phone': '',
#  'RatingValue': 0,
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2021-09-23T00:00:00',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.27694, 'latitude': 50.7697},
#  'RightToReply': '',
#  'Distance': 4613.888288172291,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0,
#           'pageSize': 0,
#           'pageNumber': 0},
#  'links': [{'rel': 'self',
#             'href': 'https://api.ratings.food.gov.uk/establishments/110681'}]}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(f'No of rows in the DataFrame are: {len(df)}')
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# No of rows in the DataFrame are: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  6532a0e27cf1a2608b4da18a   110681                  0
# 1  6532a0e27cf1a2608b4da50e   612039                  0
# 2  6532a0e27cf1a2608b4da818   730933                  0
# 3  6532a0e27cf1a2608b4daa04   172735                  0
# 4  6532a0e27cf1a2608b4daa13   172953                  0
# 5  6532a0e27cf1a2608b4db3b3   512854                  0
# 6  6532a0e27cf1a2608b4db5d1  1537089                  0
# 7  6532a0e27cf1a2608b4dcafc   155648                  0
# 8  6532a0e27cf1a2608b4dcf43  1012883                  0
# 9  6532a0e27cf1a2608b4dd754   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                         geocode RightToReply     Distance  \
# 0   {'longitude': 0.27694, 'latitude': 50.7697}               4613.888288
# 1   {'longitude': 1.27872, 'latitude': 51.8575}               4617.965824
# 2   {'longitude': 1.15927, 'latitude': 51.7894}               4619.656144
# 3   {'longitude': 0.10202, 'latitude': 50.7709}               4620.421725
# 4  {'longitude': 0.101446, 'latitude': 50.7707}               4620.437179
# 5  {'longitude': 0.736349, 'latitude': 51.5414}               4625.565258
# 6   {'longitude': 0.712167, 'latitude': 51.535}               4626.200132
# 7  {'longitude': 0.602364, 'latitude': 51.5915}               4632.276890
# 8   {'longitude': 0.14645, 'latitude': 51.1859}               4633.934041
# 9  {'longitude': 0.462307, 'latitude': 51.5701}               4636.552523
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 6            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 7            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 8            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 9            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {
    "RatingValue":{"$gte":4},
    "LocalAuthorityName":{"$regex":"London"}
    }
results = establishments.find(query)

# Use count_documents to display the number of documents in the result

print(f"No of documents in the result is: {establishments.count_documents(query)}")

# Display the first document in the results using pprint
print("Result of the first document:")
pprint(results[0], sort_dicts=False)
# Out:
# No of documents in the result is: 33
# Result of the first document:
# {'_id': ObjectId('6532a0e27cf1a2608b4dbba4'),
#  'FHRSID': 621707,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'PostCode': 'ME12',
#  'Phone': '',
#  'RatingValue': 4,
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2021-10-18T00:00:00',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.508551, 'latitude': 51.3693},
#  'RightToReply': '',
#  'Distance': 4627.439467780196,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0,
#           'pageSize': 0,
#           'pageNumber': 0},
#  'links': [{'rel': 'self',
#             'href': 'https://api.ratings.food.gov.uk/establishments/621707'}]}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(f'No of rows in the DataFrame are: {len(df)}')
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# No of rows in the DataFrame are: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  6532a0e27cf1a2608b4dbba4   621707                  0
# 1  6532a0e27cf1a2608b4dbeca  1130836                  0
# 2  6532a0e27cf1a2608b4dca16   293783                  0
# 3  6532a0e27cf1a2608b4dd819  1315095                  0
# 4  6532a0e27cf1a2608b4dd81c   294474                  0
# 5  6532a0e27cf1a2608b4ddf1d   294900                  0
# 6  6532a0e37cf1a2608b4e003c   293756                  0
# 7  6532a0e37cf1a2608b4e03f9   878523                  0
# 8  6532a0e37cf1a2608b4e040d   293772                  0
# 9  6532a0e37cf1a2608b4e040e   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000002585         The Nuance Group (UK) Limited
# 9             PI/000016185                              WH Smith
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                  Duty Free Shop Passenger Terminal
# 9                                London City Airport
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8  London City AirportRoyal DocksLondon               ...
# 9                     Silvertown London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                          geocode RightToReply     Distance  \
# 0   {'longitude': 0.508551, 'latitude': 51.3693}               4627.439468
# 1   {'longitude': 0.249256, 'latitude': 51.1236}               4627.873179
# 2   {'longitude': 0.561954, 'latitude': 51.5438}               4631.968418
# 3   {'longitude': 0.346337, 'latitude': 51.4641}               4636.846754
# 4   {'longitude': 0.346325, 'latitude': 51.4641}               4636.847650
# 5   {'longitude': 0.287555, 'latitude': 51.5041}               4640.460834
# 6   {'longitude': 0.069286, 'latitude': 51.5011}               4648.301822
# 7   {'longitude': 0.048006, 'latitude': 51.5037}               4649.173485
# 8   {'longitude': 0.047966, 'latitude': 51.5041}               4649.188826
# 9  {'longitude': 0.0479656, 'latitude': 51.5041}               4649.188850
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 6            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 7            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 8            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 9            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = establishments.find({"BusinessName":"Penang Flavours"})[0]['geocode']['latitude']
longitude = establishments.find({"BusinessName":"Penang Flavours"})[0]['geocode']['longitude']

query = {
    "RatingValue":{"$eq":5},
    "geocode.latitude":{"$lte":latitude + degree_search},
    "geocode.latitude":{"$gte":latitude - degree_search},
    "geocode.longitude":{"$lte":longitude + degree_search},
    "geocode.longitude":{"$gte":longitude - degree_search}
    }

sort = [("scores.Hygiene",1)]

limit = 5
results = establishments.find(query).sort(sort).limit(limit)


# Use count_documents to display the number of documents in the result

print(f"No of documents in the result is: {establishments.count_documents(query)


# Print the results
pprint(list(results), sort_dicts=False)
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# c:\Users\smmr8\Documents\Data Analytics Bootcamp\12-NoSQL\0_Challenge\nosql-challenge\NoSQL_analysis_starter.ipynb Cell 16 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/smmr8/Documents/Data%20Analytics%20Bootcamp/12-NoSQL/0_Challenge/nosql-challenge/NoSQL_analysis_starter.ipynb#X21sZmlsZQ%3D%3D?line=19'>20</a> results = establishments.find(query).sort(sort).limit(limit)
#      <a href='vscode-notebook-cell:/c%3A/Users/smmr8/Documents/Data%20Analytics%20Bootcamp/12-NoSQL/0_Challenge/nosql-challenge/NoSQL_analysis_starter.ipynb#X21sZmlsZQ%3D%3D?line=22'>23</a> # Use count_documents to display the number of documents in the result
# ---> <a href='vscode-notebook-cell:/c%3A/Users/smmr8/Documents/Data%20Analytics%20Bootcamp/12-NoSQL/0_Challenge/nosql-challenge/NoSQL_analysis_starter.ipynb#X21sZmlsZQ%3D%3D?line=24'>25</a> print(f"No of documents in the result is: {establishments.count_documents(results)}")
#      <a href='vscode-notebook-cell:/c%3A/Users/smmr8/Documents/Data%20Analytics%20Bootcamp/12-NoSQL/0_Challenge/nosql-challenge/NoSQL_analysis_starter.ipynb#X21sZmlsZQ%3D%3D?line=27'>28</a> # Print the results
#      <a href='vscode-notebook-cell:/c%3A/Users/smmr8/Documents/Data%20Analytics%20Bootcamp/12-NoSQL/0_Challenge/nosql-challenge/NoSQL_analysis_starter.ipynb#X21sZmlsZQ%3D%3D?line=28'>29</a> pprint(list(results), sort_dicts=False)
#
# File c:\Users\smmr8\anaconda3\envs\dev\Lib\site-packages\pymongo\collection.py:1826, in Collection.count_documents(self, filter, session, **kwargs)
#    1823         return 0
#    1824     return result['n']
# -> 1826 return self.__database.client._retryable_read(
#    1827     _cmd, self._read_preference_for(session), session)
#
# File c:\Users\smmr8\anaconda3\envs\dev\Lib\site-packages\pymongo\mongo_client.py:1525, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1521         if retrying and not retryable:
#    1522             # A retry is not possible because this server does
#    1523             # not support retryable reads, raise the last error.
#    1524             raise last_error
# -> 1525         return func(session, server, sock_info, secondary_ok)
#    1526 except ServerSelectionTimeoutError:
#    1527     if retrying:
#    1528         # The application may think the write was never attempted
#    1529         # if we raise ServerSelectionTimeoutError on the retry
#    1530         # attempt. Raise the original exception instead.
#
# File c:\Users\smmr8\anaconda3\envs\dev\Lib\site-packages\pymongo\collection.py:1820, in Collection.count_documents.<locals>._cmd(session, server, sock_info, secondary_ok)
#    1819 def _cmd(session, server, sock_info, secondary_ok):
# -> 1820     result = self._aggregate_one_result(
#    1821         sock_info, secondary_ok, cmd, collation, session)
#    1822     if not result:
#    1823         return 0
#
# File c:\Users\smmr8\anaconda3\envs\dev\Lib\site-packages\pymongo\collection.py:1685, in Collection._aggregate_one_result(self, sock_info, secondary_ok, cmd, collation, session)
#    1682 def _aggregate_one_result(
#    1683         self, sock_info, secondary_ok, cmd, collation, session):
#    1684     """Internal helper to run an aggregate that returns a single result."""
# -> 1685     result = self._command(
#    1686         sock_info,
#    1687         cmd,
#    1688         secondary_ok,
#    1689         allowable_errors=[26],  # Ignore NamespaceNotFound.
#    1690         codec_options=self.__write_response_codec_options,
#    1691         read_concern=self.read_concern,
#    1692         collation=collation,
#    1693         session=session)
#    1694     # cursor will not be present for NamespaceNotFound errors.
#    1695     if 'cursor' not in result:
#
# File c:\Users\smmr8\anaconda3\envs\dev\Lib\site-packages\pymongo\collection.py:238, in Collection._command(self, sock_info, command, secondary_ok, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, collation, session, retryable_write, user_fields)
#     209 """Internal command helper.
#     210
#     211 :Parameters:
#    (...)
#     235   The result document.
#     236 """
#     237 with self.__database.client._tmp_session(session) as s:
# --> 238     return sock_info.command(
#     239         self.__database.name,
#     240         command,
#     241         secondary_ok,
#     242         read_preference or self._read_preference_for(session),
#     243         codec_options or self.codec_options,
#     244         check,
#     245         allowable_errors,
#     246         read_concern=read_concern,
#     247         write_concern=write_concern,
#     248         parse_write_concern_error=True,
#     249         collation=collation,
#     250         session=s,
#     251         client=self.__database.client,
#     252         retryable_write=retryable_write,
#     253         user_fields=user_fields)
#
# File c:\Users\smmr8\anaconda3\envs\dev\Lib\site-packages\pymongo\pool.py:726, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     724 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     725 except BaseException as error:
# --> 726     self._raise_connection_failure(error)
#
# File c:\Users\smmr8\anaconda3\envs\dev\Lib\site-packages\pymongo\pool.py:710, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708     self._raise_if_not_writable(unacknowledged)
#     709 try:
# --> 710     return command(self, dbname, spec, secondary_ok,
#     711                    self.is_mongos, read_preference, codec_options,
#     712                    session, client, check, allowable_errors,
#     713                    self.address, check_keys, listeners,
#     714                    self.max_bson_size, read_concern,
#     715                    parse_write_concern_error=parse_write_concern_error,
#     716                    collation=collation,
#     717                    compression_ctx=self.compression_context,
#     718                    use_op_msg=self.op_msg_enabled,
#     719                    unacknowledged=unacknowledged,
#     720                    user_fields=user_fields,
#     721                    exhaust_allowed=exhaust_allowed)
#     722 except (OperationFailure, NotPrimaryError):
#     723     raise
#
# File c:\Users\smmr8\anaconda3\envs\dev\Lib\site-packages\pymongo\network.py:118, in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     116 flags = _OpMsg.MORE_TO_COME if unacknowledged else 0
#     117 flags |= _OpMsg.EXHAUST_ALLOWED if exhaust_allowed else 0
# --> 118 request_id, msg, size, max_doc_size = message._op_msg(
#     119     flags, spec, dbname, read_preference, secondary_ok, check_keys,
#     120     codec_options, ctx=compression_ctx)
#     121 # If this is an unacknowledged write then make sure the encoded doc(s)
#     122 # are small enough, otherwise rely on the server to return an error.
#     123 if (unacknowledged and max_bson_size is not None and
#     124         max_doc_size > max_bson_size):
#
# File c:\Users\smmr8\anaconda3\envs\dev\Lib\site-packages\pymongo\message.py:742, in _op_msg(flags, command, dbname, read_preference, secondary_ok, check_keys, opts, ctx)
#     739     if ctx:
#     740         return _op_msg_compressed(
#     741             flags, command, identifier, docs, check_keys, opts, ctx)
# --> 742     return _op_msg_uncompressed(
#     743         flags, command, identifier, docs, check_keys, opts)
#     744 finally:
#     745     # Add the field back to the command.
#     746     if identifier:
#
# InvalidDocument: cannot encode object: <pymongo.cursor.Cursor object at 0x0000020D9D59C290>, of type: <class 'pymongo.cursor.Cursor'>

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
